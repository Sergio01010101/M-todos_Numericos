# %% [markdown]
# <a href="https://colab.research.google.com/github/Sergio01010101/M-todos_Numericos/blob/main/Clase_del_25/08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def choclo(z):
  return np.exp(z)
choclo(0)
# Out:
# np.float64(1.0)

# %%
lista = []
for i in range(5,9):
  lista.append(i)
print(lista)
# Out:
# [5, 6, 7, 8]

# %%
sum = 0
for k in range(101):
  sum+=k
print(sum)
# Out:
# 5050

# %%
sum = 0
for k in range(2,11):
  sum+= k**2
print(sum)
# Out:
# 384

# %%
sum = 0
for j in range(0,6):
  sum += np.cos(j)
print(sum)
# Out:
# -0.2358184626798337

# %%
mult = 1
for k in range(2,11):
  mult *= k**2
print(mult)
# Out:
# 13168189440000

# %%
def facto(n):
   mult = 1
   for k in range(1,n+1):
    mult*=k
   print(mult)
facto(5)
# Out:
# 120

# %%
x = [1,2,5]
y = [10,5,1]
plt.plot(x,y,"blue", linestyle = ":", linewidth = "2")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
